# %% [markdown]
# <a href="https://colab.research.google.com/github/veniapputrii/Python/blob/Introduction/NeueAufgabe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#12. März 2026
import pandas as pd
import matplotlib.pyplot as plt
#Unsere neuen Mitarbeiter-Daten inklusive Alter!

daten= {
    'Name' : ['Lukas', 'Mia', 'Noah', 'Emma', 'Paul', 'Lea', 'Finn', 'Marie', 'Leon', 'Sofia'],
    'Abteilung' : ['IT', 'HR', 'IT', 'HR', 'IT', 'HR', 'IT', 'HR', 'IT', 'HR'],
    'Alter' : [28, 34, 29, 42, 50, 25, 38, 31, 24, 45],
    'Gehalt' : [60000, 55000, 65000, 58000, 75000, 62000, 70000, 50000, 68000, 52000]
}
df_team = pd.DataFrame(daten)
print(df_team)

#-- Schritt 1 : Filtern (Nur Mitarbeiter strikt über 30 Jahre) --
#wir erstellen die Maske und wenden sie an
df_erfahren = df_team[df_team['Alter'] > 30]
print("1. Erfahrene Mitarbeiter (Ü30):")
print('_' * 30)

#-- Schritt 2 : Gruppieren & Rechnen (Gesamtsumme der Gehälter pro ABteilung)
#Wir gruppieren nach Abteilung und berechnen die Summe (.sum()) vom Gehalt
kosten_pro_Abteilung = df_erfahren.groupby('Abteilung')['Gehalt'].sum()
print('2. Gehaltskosten der erfahrenen Mitarbeiter pro Abteilung :')
print(kosten_pro_Abteilung)
print('_' * 30)

#-- Schritt 3 : Visualisieren (Kuchendiagram) ---
#Wier zeichen ein Kuchendiagraam ('Pie')
kosten_pro_Abteilung.plot(kind= 'pie',
title= 'Gehaltskosten der Ü30-Mitarbeiter')
plt.ylabel('Abteilung') #DIeser Trick versteck den störenden Text an der Seite

#Diagram anzeigen
plt.show(kosten_pro_Abteilung)
Dateiname = "Gehaltsanalyse.xlsx"

df_team.to_excel(Dateiname, index=False)
print(f"Erfolgreich als '{Dateiname}' in Colab gespeichert!")

from google.colab import files
files.download(Dateiname)
# Out:
#     Name Abteilung  Alter  Gehalt
# 0  Lukas        IT     28   60000
# 1    Mia        HR     34   55000
# 2   Noah        IT     29   65000
# 3   Emma        HR     42   58000
# 4   Paul        IT     50   75000
# 5    Lea        HR     25   62000
# 6   Finn        IT     38   70000
# 7  Marie        HR     31   50000
# 8   Leon        IT     24   68000
# 9  Sofia        HR     45   52000
# 1. Erfahrene Mitarbeiter (Ü30):
# ______________________________
# 2. Gehaltskosten der erfahrenen Mitarbeiter pro Abteilung :
# Abteilung
# HR    215000
# IT    145000
# Name: Gehalt, dtype: int64
# ______________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2291/3997620312.py in <cell line: 0>()
#      33
#      34 #Diagram anzeigen
# ---> 35 plt.show(kosten_pro_Abteilung)
#      36 Dateiname = "Gehaltsanalyse.xlsx"
#      37
#
# ...
